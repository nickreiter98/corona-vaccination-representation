# %%
# import all necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.options.display.max_rows = 999

# %%
df = pd.read_csv('data.csv')

# %% [markdown]
# ## Data Representation

# %%
df
# Out:
#        YearWeekISO ReportingCountry  Denominator  NumberDosesReceived  \
# 0         2021-W05               AT     423433.0                  0.0
# 1         2023-W10               AT    1543886.0                  0.0
# 2         2023-W10               AT    1047888.0                  0.0
# 3         2023-W10               AT     258398.0                  0.0
# 4         2023-W10               AT    7388778.0                  0.0
# ...            ...              ...          ...                  ...
# 681325    2021-W25               SK          NaN                  0.0
# 681326    2021-W25               SK    4431608.0                  0.0
# 681327    2021-W25               SK     159879.0                  0.0
# 681328    2021-W25               SK     388502.0                  0.0
# 681329    2021-W20               SK     688658.0                  0.0
#
#         NumberDosesExported  FirstDose  FirstDoseRefused  SecondDose  \
# ...

# %%
df['ReportingCountry'].unique()
# Out:
# array(['AT', 'BE', 'BG', 'CY', 'CZ', 'DE', 'DK', 'EE', 'EL', 'ES', 'FI',
#        'FR', 'HR', 'HU', 'IE', 'IS', 'IT', 'LI', 'LT', 'LU', 'LV', 'MT',
#        'NL', 'NO', 'PL', 'PT', 'RO', 'SE', 'SI', 'SK'], dtype=object)

# %%
df['YearWeekISO'].unique()
# Out:
# array(['2021-W05', '2023-W10', '2022-W09', '2022-W08', '2023-W09',
#        '2022-W07', '2023-W08', '2021-W42', '2021-W41', '2022-W48',
#        '2021-W51', '2021-W50', '2023-W07', '2021-W49', '2021-W15',
#        '2021-W16', '2023-W06', '2021-W48', '2023-W05', '2021-W40',
#        '2021-W39', '2021-W38', '2021-W37', '2022-W27', '2022-W26',
#        '2021-W36', '2021-W35', '2021-W47', '2023-W04', '2023-W03',
#        '2023-W02', '2021-W46', '2023-W01', '2021-W45', '2022-W52',
#        '2021-W44', '2021-W43', '2022-W51', '2022-W50', '2021-W34',
#        '2021-W33', '2021-W32', '2021-W31', '2022-W25', '2022-W24',
#        '2021-W30', '2021-W29', '2022-W37', '2022-W38', '2022-W39',
#        '2021-W28', '2022-W40', '2022-W06', '2023-W16', '2023-W15',
#        '2022-W49', '2022-W13', '2022-W28', '2023-W14', '2022-W41',
#        '2021-W21', '2021-W22', '2023-W13', '2021-W01', '2022-W23',
#        '2022-W22', '2022-W21', '2022-W36', '2022-W20', '2022-W47',
# ...

# %%
df['TargetGroup'].unique()
# Out:
# array(['Age10_14', 'Age<18', 'Age60_69', 'Age15_17', 'ALL', 'Age5_9',
#        'Age18_24', 'Age0_4', 'Age70_79', 'Age80+', 'Age25_49', 'Age50_59',
#        'HCW', 'AgeUNK', 'LTCF', '1_Age60+', '1_Age<60'], dtype=object)

# %%
df['Vaccine'].unique()
# Out:
# array(['AZ', 'NVXD', 'MODBA.1', 'MOD', 'SGSK', 'VLA', 'UNK', 'COM',
#        'COMBA.4-5', 'COMBA.1', 'JANSS', 'MODBA.4-5', 'MODBIV', 'COMBIV',
#        'SPU', 'BECNBG', 'SIN', 'BHACOV'], dtype=object)

# %%
de_under18 = df[(df['TargetGroup']=='Age<18')&(df['ReportingCountry']=='DE')].sort_values(by=['YearWeekISO']).reset_index(drop=True)

# %%
de_under18.size
# Out:
# 2160

# %%
plt.plot(de_under18['YearWeekISO'].to_list(), de_under18['FirstDose'].to_list())
plt.xticks([0,de_under18.shape[0]], [de_under18['YearWeekISO'].iloc[0], de_under18['YearWeekISO'].iloc[-1]], visible=True, rotation="horizontal")
# Out:
# ([<matplotlib.axis.XTick at 0x21511b9fbe0>,
# ...
#  [Text(0, 0, '2020-W52'),
#   Text(0, 1, '2020-W52'),
#   Text(0, 0, '2023-W14'),
#   Text(0, 1, '2023-W14')])
